# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'C:\Users\ACER\Desktop\Projects\Machine Learning Based Real Estate System\Dataset\Cleaned_Properties_V2.csv').drop_duplicates()
df.head()
# Out:
#   property_type                   society      sector  price  price_per_sqft  \
# 0          flat        umang winter hills   sector 77   1.00          7500.0
# 1          flat  emaar mgf emerald estate   sector 65   1.75         12544.0
# 2         house          suncity township   sector 54   2.00         30968.0
# 3         house               independent  sector 108   1.70          5666.0
# 4          flat            dlf the ultima   sector 81   2.30         10994.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1333.0                   Carpet area: 1340 (124.49 sq.m.)        2
# 1  1395.0  Super Built up area 1395(129.6 sq.m.)Carpet ar...        3
# 2   646.0  Plot area 60Built Up area: 60 sq.m.Carpet area...        9
# 3  3000.0  Built Up area: 3000 (278.71 sq.m.)Carpet area:...        4
# 4  2092.0             Super Built up area 2092(194.35 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
df.shape
# Out:
# (3728, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %% [markdown]
# ### price

# %%
# Outliers on the Basis of Price Column
sns.distplot(df['price'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\3343439101.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])

# %%
sns.boxplot(x=df['price'])
plt.show()

# %%
# Calculate the IQR for the 'price' Column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify Outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (431,
#  count    431.000000
#  mean       9.214478
#  std        4.064876
#  min        5.460000
#  25%        6.420000
#  50%        8.000000
#  75%       10.655000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price', ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 92           house  arjun marg/ sector- 26 phase- 1/ golf course road
# 3831         house                                        independent
# 2336         house                                        independent
# 3678         house                                     dlf city plots
# 2431         house                                   suncity township
# 3076         house                             emaar the palm springs
# 841          house                                        independent
# 3516         house                                 vipul tatvam villa
# 3304         house                                        independent
# 836          house                             luxury dlf city floors
# 3135         house                                     dlf city plots
# 997          house                                 vipul tatvam villa
# ...

# %% [markdown]
# On the basis of Price column we can state that there are some genuine outliers but there are some data error as well

# %% [markdown]
# ### price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\575062949.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])

# %%
sns.boxplot(x=df['price_per_sqft'])
plt.show()

# %%
# Calculate the IQR for the 'price_per_sqft' Column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify Outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers_sqft and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (358,
#  count       358.000000
#  mean      52644.340782
#  std       60826.009563
#  min       24489.000000
#  25%       28241.250000
#  50%       33628.500000
#  75%       42159.000000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      358.000000
# mean     29189.209497
# std      12503.452307
# min       2723.000000
# 25%      25546.250000
# 50%      29788.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\575062949.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])

# %%
sns.boxplot(x=df['price_per_sqft'])
plt.show()

# %%
df[df['price_per_sqft'] > 50000]
# Out:
#      property_type                       society           sector  price  \
# 104          house                  malibu towne        sector 47   8.50
# 467          house            emaar mgf marbella        sector 66  18.00
# 871          house                           nul        sector 28  12.50
# 885          house  project housing board colony        sector 31   8.00
# 1921         house                unitech escape        sector 50  10.80
# 2336         house                   independent        sector 26  26.00
# 2622         house                   independent        sector 25  16.00
# 2753          flat                unitech vistas        sector 70   9.00
# 3076         house        emaar the palm springs        sector 54  24.00
# 3091         house            cloudnine cottages  sohna road road   5.50
# 3154         house        emaar the palm springs        sector 54  14.00
# 3678         house                dlf city plots        sector 26  26.00
# ...

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
plt.show()

# %% [markdown]
# ### area

# %%
sns.distplot(df['area'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\2660226674.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])

# %%
sns.boxplot(x=df['area'])
plt.show()

# %%
df['area'].describe()
# Out:
# count      3698.000000
# mean       2951.555435
# std       23064.729602
# min         145.000000
# 25%        1260.250000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society           sector  price  \
# 1941          flat      signature the roselia        sector 95   0.45
# 1989         house                independent        sector 50   5.00
# 2841          flat            ramsons kshitij        sector 95   0.31
# 3045          flat          hcbs sports ville  sohna road road   0.35
# 3415          flat  signature global solera 2       sector 107   0.51
#
#       price_per_sqft      area                           areaWithType  \
# 1941             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 1989           232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 2841             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 3045             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 3415             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\2660226674.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])

# %%
sns.boxplot(x=df['area'])
plt.show()

# %%
df[df['area'] > 10000].sort_values('area', ascending=False)

# 2218, 241, 3809, 3203, 1537, 1339, 377, 341, 3707
# Out:
#      property_type                    society           sector  price  \
# 2808         house                independent        sector 26  18.40
# 2256         house  ganpati heights apartment        sector 13   1.25
# 241           flat                 rof ananda        sector 95   0.38
# 3809          flat                 rof ananda        sector 95   0.38
# 385          house      dlf city plot phase 4        sector 28  13.00
# 3203          flat              pyramid elite        sector 86   0.46
# 1537          flat                 rof ananda        sector 95   0.33
# 3345         house                independent        sector 51   5.50
# 1339          flat      signature the serenas  sohna road road   0.28
# 1408         house                independent        sector 25   7.30
# 377           flat            ramsons kshitij        sector 95   0.24
# 341           flat                 rof ananda        sector 95   0.21
# ...

# %%
df.drop(index=[2218, 241, 3809, 3203, 1537, 1339, 377, 341, 3707], inplace=True)

# %%
pd.set_option('display.max_colwidth', None)
df[df['area'] > 10000].sort_values('area', ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 2808         house                independent        sector 26  18.40
# 2256         house  ganpati heights apartment        sector 13   1.25
# 385          house      dlf city plot phase 4        sector 28  13.00
# 3345         house                independent        sector 51   5.50
# 1408         house                independent        sector 25   7.30
# 2177         house                independent        sector 57   6.25
# 2007         house                independent        sector 43   5.50
# 491           flat                 godrej air        sector 85   2.50
# 1145         house       unitech aspen greens        sector 50   6.95
# 3162         house                independent         sector 4   0.85
# 451           flat                godrej icon       sector 88a   1.75
# 3831         house                independent        sector 43  27.50
# ...

# %%
df.loc[2808, 'area'] = 11000
df.loc[2256, 'area'] = 115*9
df.loc[385, 'area'] = 7250
df.loc[3345, 'area'] = 8260
df.loc[1408, 'area'] = 5800
df.loc[2177, 'area'] = 2660 
df.loc[2007, 'area'] = 2850 
df.loc[491, 'area'] = 1812
df.loc[1145, 'area'] = 2160 
df.loc[3162, 'area'] = 1500
df.loc[451, 'area'] = 1175
df.loc[3831, 'area'] = 1254
df.loc[336, 'area'] = 1100
df.loc[1697, 'area'] = 3500

# %%
pd.reset_option('display.max_colwidth')

# %%
sns.distplot(df['area'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\2660226674.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])

# %%
sns.boxplot(x=df['area'])
plt.show()

# %%
df['area'].describe()
# Out:
# count     3684.000000
# mean      1945.276873
# std       1200.035674
# min        145.000000
# 25%       1258.750000
# 50%       1745.000000
# 75%       2326.000000
# max      11000.000000
# Name: area, dtype: float64

# %% [markdown]
# ### bedroom

# %%
sns.distplot(df['bedRoom'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\592609350.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])

# %%
sns.boxplot(x=df['bedRoom'])
plt.show()

# %%
df['bedRoom'].describe()
# Out:
# count    3684.000000
# mean        3.347720
# std         1.900853
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        34.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom', ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 2280         house                manohar nagar    sector 5   5.60
# 59           house                  independent   sector 54   5.00
# 1111         house                  independent   sector 43   4.50
# 1810         house                  independent  sector 17a   3.87
# 1258         house                  independent  sector 17a   3.93
# 791          house                private house   sector 55   7.05
# 877          house                  independent   sector 54   5.50
# 3135         house               dlf city plots   sector 26  20.00
# 1465         house                  independent   sector 43  13.50
# 1997         house                  independent    sector 4   4.50
# 836          house       luxury dlf city floors   sector 26  20.00
# 999          house                  independent   sector 56  12.39
# 3288         house                  independent   sector 40  12.00
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3637, 23)

# %%
sns.distplot(df['bedRoom'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\592609350.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])

# %%
sns.boxplot(x = df['bedRoom'])
plt.show()

# %%
df['bedRoom'].describe()
# Out:
# count    3637.000000
# mean        3.209238
# std         1.399333
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\2878137229.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])

# %%
sns.boxplot(x=df['bathroom'])
plt.show()

# %%
df[df['bathroom'] > 10].sort_values('bathroom', ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 1914         house  adani brahma samsara  sector 60  18.02         28200.0
# 3064         house           independent  sector 24  11.00         28902.0
# 3397         house           independent  sector 39   7.00         10000.0
#
#         area                                       areaWithType  bedRoom  \
# 1914  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 3064  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
# 3397  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 1914        12      3+       3.0  North-East  Relatively New
# 3064        11      3+       3.0        East    Old Property
# 3397        11      3+       4.0  South-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %% [markdown]
# ### Super Built Up Area

# %%
sns.distplot(df['super_built_up_area'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\1351349074.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])

# %%
sns.boxplot(x=df['super_built_up_area'])
plt.show()

# %%
df['super_built_up_area'].describe()
# Out:
# count     1880.000000
# mean      1923.666782
# std        763.981194
# min         89.000000
# 25%       1477.250000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society     sector  price  \
# 2359          flat  bestech park view grand spa  sector 81    4.7
# 3391          flat       krrish provence estate   sector 2    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 2359          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 3391          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 2359        4         4      3+      19.0       North  Relatively New
# 3391        5         6      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 2359               6926.0            NaN          NaN           0
# 3391              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ### Built Up Area

# %%
sns.distplot(df['built_up_area'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\732662566.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])

# %%
sns.boxplot(x=df['built_up_area'])
plt.show()

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft    area  \
# 3162         house  independent   sector 4   0.85           630.0  1500.0
# 3831         house  independent  sector 43  27.50         24366.0  1254.0
#
#                        areaWithType  bedRoom  bathroom balcony  floorNum  \
# 3162  Plot area 1500(1254.19 sq.m.)        3         3       1       1.0
# 3831   Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 3162       North  Relatively New                  NaN        13500.0
# 3831  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 3162          NaN           0             0           0           0       1
# 3831          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 3162                1             0
# ...

# %% [markdown]
# ### Carpet Area

# %%
df[df['carpet_area'] > 12000]
# Out:
#     property_type     society     sector  price  price_per_sqft    area  \
# 491          flat  godrej air  sector 85    2.5          1379.0  1812.0
#
#                            areaWithType  bedRoom  bathroom balcony  floorNum  \
# 491  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
#
#          facing   agePossession  super_built_up_area  built_up_area  \
# 491  North-East  Relatively New                  NaN            NaN
#
#      carpet_area  study room  servant room  store room  pooja room  others  \
# 491      18122.0           1             0           0           1       1
#
#      furnishing_type  luxury_score
# 491                0            44

# %%
df.drop(index=[491], inplace=True)

# %%
sns.distplot(df['carpet_area'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\102693169.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])

# %%
sns.boxplot(x=df['carpet_area'])
plt.show()

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 336           flat  m3m golfestate  sector 65   13.2         12000.0   1100.0
# 2808         house     independent  sector 26   18.4          1859.0  11000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 336                  Carpet area: 11000 (1021.93 sq.m.)        4         4
# 2808  Plot area 502(419.74 sq.m.)Carpet area: 11000 ...        6         8
#
#      balcony  floorNum facing   agePossession  super_built_up_area  \
# 336        3      13.0  North  Moderately New                  NaN
# 2808      3+       4.0  South  Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 336             NaN      11000.0           0             1           0
# 2808            NaN      11000.0           0             1           1
#
#       pooja room  others  furnishing_type  luxury_score
# ...

# %%
df.drop(index=[2808], inplace=True)

# %% [markdown]
# ### Luxury Score

# %%
sns.distplot(df['luxury_score'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\1178651402.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])

# %%
sns.boxplot(x=df['luxury_score'])
plt.show()

# %% [markdown]
# ### Price_Per_SQFT

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                   society      sector  price  price_per_sqft  \
# 0          flat        umang winter hills   sector 77   1.00          7502.0
# 1          flat  emaar mgf emerald estate   sector 65   1.75         12545.0
# 2         house          suncity township   sector 54   2.00          3440.0
# 3         house               independent  sector 108   1.70          5667.0
# 4          flat            dlf the ultima   sector 81   2.30         10994.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1333.0                   Carpet area: 1340 (124.49 sq.m.)        2
# 1  1395.0  Super Built up area 1395(129.6 sq.m.)Carpet ar...        3
# 2  5814.0  Plot area 60Built Up area: 60 sq.m.Carpet area...        9
# 3  3000.0  Built Up area: 3000 (278.71 sq.m.)Carpet area:...        4
# 4  2092.0             Super Built up area 2092(194.35 sq.m.)        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
df[df['price_per_sqft'] > 100000]
# Out:
#      property_type         society     sector  price  price_per_sqft    area  \
# 336           flat  m3m golfestate  sector 65   13.2        120000.0  1100.0
# 3831         house     independent  sector 43   27.5        219298.0  1254.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 336   Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
# 3831        Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 336        North  Moderately New                  NaN            NaN
# 3831  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 336       11000.0           0             1           0           0       0
# 3831          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# ...

# %%
df.drop(index=[336, 3831], inplace=True)

# %%
sns.distplot(df['price_per_sqft'])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20740\575062949.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])

# %%
sns.boxplot(x=df['price_per_sqft'])
plt.show()

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 150          house                   independent   sector 26   19.0
# 332          house                   independent   sector 28   12.0
# 414          house                   independent  sector 105    9.9
# 615          house  sushant lok 1 builder floors   sector 43   13.0
# 1026         house                   independent   sector 55    5.0
# 2116         house                   independent   sector 25   13.0
# 2379         house                   independent   sector 43    9.5
# 3304         house                   independent   sector 26   20.0
# 3759         house                dlf city plots   sector 26   19.0
#
#       price_per_sqft    area  \
# 150          42222.0  4500.0
# 332          42194.0  2844.0
# 414          49500.0  2000.0
# 615          48148.0  2700.0
# 1026         44444.0  1125.0
# 2116         45710.0  2844.0
# 2379         42222.0  2250.0
# 3304         44444.0  4500.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.02)
# Out:
# 180.0

# %%
df[(df['area']/df['bedRoom'])<180]
# Out:
#      property_type                          society      sector  price  \
# 23           house                      independent    sector 4   0.92
# 56           house                      independent   sector 24   4.50
# 80           house                      independent  sector 104   0.71
# 111          house  ashok vihar phase iii extension    sector 3   0.40
# 140          house            rajendra park gurgaon  sector 105   0.37
# ...            ...                              ...         ...    ...
# 3557         house                      independent    sector 7   0.89
# 3603         house                            ansal   sector 43   1.85
# 3629         house                      independent    sector 7   0.27
# 3662         house                      independent    sector 2   1.00
# 3664         house             housing board colony   sector 28   2.10
#
#       price_per_sqft    area  \
# 23           15257.0   603.0
# 56           33333.0  1350.0
# ...

# %%
df.to_csv(r'C:\Users\ACER\Desktop\Projects\Machine Learning Based Real Estate System\Dataset\Cleaned_Properties_V3.csv', index=False)
