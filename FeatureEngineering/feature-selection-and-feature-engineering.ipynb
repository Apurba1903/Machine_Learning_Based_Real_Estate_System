# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'C:\Users\ACER\Desktop\Projects\Machine Learning Based Real Estate System\Dataset\Cleaned_Properties_V4.csv')

# %%
df.shape
# Out:
# (3632, 18)

# %%
df.head()
# Out:
#   property_type                   society      sector  price  price_per_sqft  \
# 0          flat        umang winter hills   sector 77   1.00          7502.0
# 1          flat  emaar mgf emerald estate   sector 65   1.75         12545.0
# 2         house          suncity township   sector 54   2.00          3440.0
# 3         house               independent  sector 108   1.70          5667.0
# 4          flat            dlf the ultima   sector 81   2.30         10994.0
#
#    bedRoom  bathroom balcony  floorNum   agePossession  built_up_area  \
# 0        2         2       2       3.0    New Property         1489.0
# 1        3         3       3      10.0  Relatively New         1081.0
# 2        9         9       3      11.0  Relatively New           60.0
# 3        4         4      3+       1.0  Relatively New         3000.0
# 4        3         4      3+       6.0    New Property         1893.0
#
#    study room  servant room  store room  pooja room  others  furnishing_type  \
# 0           0             0           0           0       0                1
# 1           0             1           0           0       0                0
# 2           0             1           0           0       0                2
# 3           0             0           0           0       0                1
# 4           0             1           0           0       0                2
#
#    luxury_score
# 0            74
# 1           124
# 2             7
# 3             0
# 4           167

# %%
train_df = df.drop(columns=['society', 'price_per_sqft'])

# %%
train_df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony  floorNum  \
# 0          flat   sector 77   1.00        2         2       2       3.0
# 1          flat   sector 65   1.75        3         3       3      10.0
# 2         house   sector 54   2.00        9         9       3      11.0
# 3         house  sector 108   1.70        4         4      3+       1.0
# 4          flat   sector 81   2.30        3         4      3+       6.0
#
#     agePossession  built_up_area  study room  servant room  store room  \
# 0    New Property         1489.0           0             0           0
# 1  Relatively New         1081.0           0             1           0
# 2  Relatively New           60.0           0             1           0
# 3  Relatively New         3000.0           0             0           0
# 4    New Property         1893.0           0             1           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1            74
# 1           0       0                0           124
# 2           0       0                2             7
# 3           0       0                1             0
# 4           0       0                2           167

# %%
sns.heatmap(train_df.corr(numeric_only=True))
plt.show()

# %%
train_df.corr(numeric_only=True)['price'].sort_values(ascending=False)
# Out:
# price              1.000000
# built_up_area      0.731020
# bathroom           0.603204
# bedRoom            0.522262
# servant room       0.394283
# pooja room         0.320225
# store room         0.313166
# study room         0.241759
# luxury_score       0.102963
# others            -0.019713
# floorNum          -0.081918
# furnishing_type   -0.114035
# Name: price, dtype: float64

# %%
# Columns in Question

# numerical -> luxury_score, others, floorNum
# categorical -> property_type, sector, agePossession
