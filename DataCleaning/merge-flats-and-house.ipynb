# %%
import pandas as pd
import numpy as np

# %%
flats = pd.read_csv("C:\\Users\\ACER\Desktop\\Projects\\Machine Learning Based Real Estate System\\Dataset\\flats_cleaned.csv")
houses  = pd.read_csv("C:\\Users\\ACER\Desktop\\Projects\\Machine Learning Based Real Estate System\\Dataset\\house_cleaned.csv")

# %%
df = pd.concat([flats, houses], ignore_index=True)

# %%
df = df.sample(df.shape[0], ignore_index=True)

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                 2 BHK Flat in Sector 77 Gurgaon          flat
# 1                 3 BHK Flat in Sector 65 Gurgaon          flat
# 2   9 Bedroom House for sale in Sector 54 Gurgaon         house
# 3  4 Bedroom House for sale in Sector 108 Gurgaon         house
# 4                 3 BHK Flat in Sector 81 Gurgaon          flat
#
#                     society  price  price_per_sqft    area  \
# 0        umang winter hills   1.00          7500.0  1333.0
# 1  emaar mgf emerald estate   1.75         12544.0  1395.0
# 2          suncity township   2.00         30968.0   646.0
# 3               independent   1.70          5666.0  3000.0
# 4            dlf the ultima   2.30         10994.0  2092.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 1340 (124.49 sq.m.)        2         2
# 1  Super Built up area 1395(129.6 sq.m.)Carpet ar...        3         3
# ...

# %%
df.to_csv('Cleaned_properties.csv', index=False)
